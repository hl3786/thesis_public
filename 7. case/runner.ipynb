# %%
pwd()
# Out:
# "c:\\Users\\henry\\Thesis\\7. Cases\\PG_PJM_case_2"

# %%
ENV["GENX_PRECOMPILE"] = "true" 
using Gurobi
using GenX

# Join the current directory path with the path to your specific period 1 inputs
input_dir = joinpath(dirname(@__FILE__))

# Run the case pointing to the folder that contains 'system'
run_genx_case!(input_dir, Gurobi.Optimizer)
# Out:
#   ____           __  __   _ _
#  / ___| ___ _ __ \ \/ /  (_) |
# | |  _ / _ \ '_ \ \  /   | | |
# | |_| |  __/ | | |/  \ _ | | |
#  \____|\___|_| |_/_/\_(_)/ |_|
#                        |__/
#  Version: 0.4.5
#
# Configuring Settings
# Configuring Solver
# Loading Inputs
# Reading Input CSV Files
# Network.csv Successfully Read!
# Demand (load) data Successfully Read!
# Fuels_data.csv Successfully Read!
# [ Info: Hydro.csv Successfully Read.
# [ Info: Thermal.csv Successfully Read.
# Summary of resources loaded into the model:
# -------------------------------------------------------
# 	Resource type 		Number of resources
# ...
# 	Thermal        		88
# 	VRE            		70
# 	Storage        		15
# 	Must_run       		17
# ...
# Total number of resources: 190
# -------------------------------------------------------
# [ Info: Vre.csv Successfully Read.
# [ Info: Storage.csv Successfully Read.
# [ Info: Must_run.csv Successfully Read.
# ...
